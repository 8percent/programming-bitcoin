# %% [markdown]
# <a href="https://colab.research.google.com/github/8percent/programming-bitcoin/blob/main/colab_%EC%9D%84_%EC%82%AC%EC%9A%A9%ED%95%A0_%EC%88%98_%EC%9E%88%EC%9D%84_%EC%A7%80_%EA%B2%80%EC%A6%9D%ED%95%B4%EB%B3%B4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 소스코드가 받아지는지 확인해봤습니다. 
# !git clone https://github.com/jimmysong/programmingbitcoin
# Out:
# Cloning into 'programmingbitcoin'...
# remote: Enumerating objects: 6406, done.
# remote: Total 6406 (delta 0), reused 0 (delta 0), pack-reused 6406
# Receiving objects: 100% (6406/6406), 39.43 MiB | 26.43 MiB/s, done.
# Resolving deltas: 100% (4254/4254), done.

# %%
# 받아집니다.

# %%
# 폴더로 이동하는 것이 가능한지 시도해보았습니다.
# !cd programmingbitcoin/

# %%
# !ls
# Out:
# programmingbitcoin  sample_data

# %%
# 제자리입니다. 이동은 되지 않습니다.

# %%
# 폴더 내부를 들여다 보았습니다.
# !ls programmingbitcoin/
# Out:
# all.asciidoc	 ch09.asciidoc	code-ch08	     preface.asciidoc
# appa.asciidoc	 ch10.asciidoc	code-ch09	     README.md
# atlas.json	 ch11.asciidoc	code-ch10	     requirements.txt
# author_bio.html  ch12.asciidoc	code-ch11	     sample_chapter.asciidoc
# callouts	 ch13.asciidoc	code-ch12	     setup.cfg
# ch01.asciidoc	 ch14.asciidoc	code-ch13	     test.py
# ch02.asciidoc	 code-ch01	colo.html	     theme
# ch03.asciidoc	 code-ch02	copyright.html	     titlepage.html
# ch04.asciidoc	 code-ch03	cover.html	     toc.html
# ch05.asciidoc	 code-ch04	foreword.html	     tools
# ch06.asciidoc	 code-ch05	generate_jupyter.py  tx.cache
# ch07.asciidoc	 code-ch06	images
# ch08.asciidoc	 code-ch07	ix.html

# %%
# 소스코드들과 몇몇 파일들이 보입니다.

# %%
# 필요한 패키지가 무엇이 있는지 알아보았습니다.
# !cat programmingbitcoin/requirements.txt
# Out:
# jupyter
# requests

# %%
# 생각보다 별게 없습니다. 이미 notebook 은 실행중이어서 설치가 필요 없고, requests 가 설치 가능한지 검증해봐야 합니다.

# %%
# 설치를 해봤습니다.
# !pip install requests

# %%
# 잘 설치가 됩니다.

# %%
# 다른 셀에서 import 후 사용 가능한지 확인해보았습니다.
import requests

requests.get('https://naver.com')
# Out:
# <Response [200]>

# %%
# asciidoc 이 뭘까?
! cat programmingbitcoin/ch01.asciidoc
# Out:
# [[chapter_finite_fields]]
# [role="pagenumrestart"]
# == Finite Fields
#
# [.lead]
# One of the most difficult things about learning how to program Bitcoin is knowing where to start.
# There are so many components that depend on each other that learning one thing may lead you to have to learn another, which in turn may lead you to need to learn something else before you can understand the original thing.
#
# This((("Bitcoin", "overview of components")))((("elliptic curve cryptography", "role in Bitcoin")))((("signing and verification", "purpose of")))((("transactions", "role in Bitcoin"))) chapter is going to get you off to a more manageable start.
# It may seem strange, but we'll start with the basic math that you need to understand elliptic curve cryptography.
# Elliptic curve cryptography, in turn, gives us the signing and verification algorithms.
# These are at the heart of how transactions work, and transactions are the atomic unit of value transfer in Bitcoin.
# ...

# %%
# 책 원문 내용을 ascii 코드만 가지고 작성해 놓은 것 같습니다. 챕터 1원 내용과 동일해보입니다. (영어 잘하면 책 안사고도 공부할 수 있었다?)

# %%
# 코드 확인
# !ls programmingbitcoin/code-ch01
# Out:
# answers.py  Chapter1.ipynb  ecc.py  examples.py  helper.py  jupyter.txt

# %%
# !cat programmingbitcoin/code-ch01/examples.py
# Out:
# """
# # tag::example1[]
# >>> from ecc import FieldElement
# >>> a = FieldElement(7, 13)
# >>> b = FieldElement(6, 13)
# >>> print(a == b)
# False
# >>> print(a == a)
# True
#
# # end::example1[]
# # tag::example2[]
# >>> print(7 % 3)
# 1
#
# # end::example2[]
# # tag::example3[]
# >>> print(-27 % 13)
# 12
#
# # end::example3[]
# # tag::example4[]
# >>> from ecc import FieldElement
# >>> a = FieldElement(7, 13)
# >>> b = FieldElement(12, 13)
# >>> c = FieldElement(6, 13)
# >>> print(a+b==c)
# True
#
# # end::example4[]
# # tag::example5[]
# >>> from ecc import FieldElement
# >>> a = FieldElement(3, 13)
# >>> b = FieldElement(12, 13)
# >>> c = FieldElement(10, 13)
# >>> print(a*b==c)
# True
#
# # end::example5[]
# # tag::example6[]
# >>> from ecc import FieldElement
# >>> a = FieldElement(3, 13)
# >>> b = FieldElement(1, 13)
# >>> print(a**3==b)
# True
#
# # end::example6[]
# # tag::example7[]
# >>> from ecc import FieldElement
# >>> a = FieldElement(7, 13)
# ...

# %%
>>> from ecc import FieldElement
>>> a = FieldElement(7, 13)
>>> b = FieldElement(6, 13)
>>> print(a == b)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-26-7e4252e0aeba> in <module>()
# ----> 1 from ecc import FieldElement
#       2 a = FieldElement(7, 13)
#       3 b = FieldElement(6, 13)
#       4 print(a == b)
#
# ModuleNotFoundError: No module named 'ecc'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# .py 파일은 단순히 .ipynb 의 출력을 긁어서 복사한 것으로 보입니다.

# %%
# !cat programmingbitcoin/code-ch01/Chapter1.ipynb
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "############## PLEASE RUN THIS CELL FIRST! ###################\n",
#     "\n",
#     "# import everything and define a test runner function\n",
#     "from importlib import reload\n",
#     "from helper import run\n",
#     "import ecc\n",
#     "import helper\n",
#     "\n",
#     "from ecc import FieldElement"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "from ecc import FieldElement\n",
#     "a = FieldElement(7, 13)\n",
#     "b = FieldElement(6, 13)\n",
#     "print(a == b)\n",
#     "print(a == a)"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "### Exercise 1\n",
#     "\n",
# ...

# %%
# .ipynb 파일도 cat 명령으로 보고 사용하기에는 어려움으로 소스코드는 우리 repo 에 올려놓는것이 좋을 것 같습니다. 올려놓겠습니다.

# %%
# 잘 작동하는 것을 확인했습니다.

# %%
# 결론적으로 colab 사용하는데에는 문제가 없을 것 같습니다.
# 파이썬 버전은 3.5 이상 권장인데, 현재 3.7 인 것으로 확인되었습니다.
# 패키지도 외부 http 요청이 필요한 예제가 있어서 사용하는 것 같습니다. 여튼 잘 동작하니 문제 없습니다.
# 다만 소스코드를 colab 에서 확인하는 것은 불편하므로 repo 에 올려두도록 하겠습니다.
